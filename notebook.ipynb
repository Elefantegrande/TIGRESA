# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 6, 5]

# Crear gráfico de dispersión
plt.scatter(x, y)

# Títulos y etiquetas
plt.title("Gráfico de Dispersión Simple")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")

# Mostrar gráfico
plt.show()
